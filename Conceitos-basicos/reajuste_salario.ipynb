# %% [markdown]
# <a href="https://colab.research.google.com/github/mogimassaki/ADS-exerc-cios/blob/main/Conceitos-basicos/reajuste_salario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
salario_atual = float(input())
reajuste_percentual = float(input())
valor_reajuste = (salario_atual * reajuste_percentual) / 100
salario_final = salario_atual + valor_reajuste
print(f'{salario_final:.2f}')
# Out:
# 80.00
# 4.50
# 83.60

# %% [markdown]
# ![screenshot.jpg](data:image/jpeg;base64,...)
