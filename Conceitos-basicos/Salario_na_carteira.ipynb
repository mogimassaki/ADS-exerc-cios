# %% [markdown]
# <a href="https://colab.research.google.com/github/mogimassaki/ADS-exercicios/blob/main/Conceitos-basicos/Salario_na_carteira.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![screenshot.jpg](data:image/jpeg;base64,...)

# %%
#Entrada:
valor_antes = int(input('Digite o valor antes do serviço: '))
valor_servico = int(input('Digite o valor do serviço: '))

#Processamento:
valor_final = valor_antes + valor_servico

#Saida:
print(valor_final)
