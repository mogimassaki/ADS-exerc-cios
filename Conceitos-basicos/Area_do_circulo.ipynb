# %% [markdown]
# <a href="https://colab.research.google.com/github/mogimassaki/ADS-exercicios/blob/main/Conceitos-basicos/Area_do_circulo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Entrada
diametro = float(input())

#Constante
PI = 3.1415

#Processamento

raio = diametro/2
area = PI * (raio ** 2)

#saida
print(f'{area:.2f}')

# %% [markdown]
# ![screenshot.jpg](data:image/jpeg;base64,...)
